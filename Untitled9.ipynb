# %%
import pandas as pd
from sqlalchemy import create_engine
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
engine = create_engine("postgres://postgres:postgres@localhost:5432/cricket")
def get_df():
    query = 'select * from "players21";'
    df = pd.read_sql(query, engine)
    return df

def completedf():
    query = 'select * from "2021";'
    datadf = pd.read_sql(query, engine)
    return datadf

def olddf():
    query = 'select * from "players";'
    datadf = pd.read_sql(query, engine)
    return datadf
df = get_df()
datadf = completedf()
odf = olddf()
y = datadf.groupby(["fullName"])["tp"].describe()
y = y.fillna(0)
df = pd.merge(df, y, left_on=["Name"], right_on="fullName", how='left')
df = df.sort_values(by=['tp'], ascending=False)
a = odf[['Name', 'tp']]
tdf = pd.merge(df, a, left_on='Name', right_on='Name', how='outer')
tdf = tdf.fillna(0)
tdf.drop(['index','mean', 'min', '25%', '50%', '75%', 'max'], axis=1, inplace=True)
tdf['dif'] = tdf['tp_y'] - tdf['tp_x']

# %%
f = datadf.groupby(["city", "team", "battingfirst"])["tscore"].mean().unstack(level="city")

# %%
f
# Out:
# city                                      Abu Dhabi   Ahmedabad  Chennai  \
# team                        battingfirst
# Chennai Super Kings         False               NaN         NaN      NaN
#                             True                NaN         NaN      NaN
# Delhi Capitals              False               NaN  164.333333    138.0
#                             True                NaN         NaN    159.0
# Kolkata Knight Riders       False              94.0  126.000000    154.0
#                             True                NaN  154.000000    187.0
# Mumbai Indians              False               NaN         NaN      NaN
#                             True                NaN         NaN    145.8
# Punjab Kings                False               NaN         NaN    132.0
#                             True                NaN  156.000000    120.0
# Rajasthan Royals            False               NaN         NaN      NaN
# ...

# %%
g = datadf.groupby(["city", "team", "battingfirst"])["twkts"].mean().unstack(level="city")

# %%
g
# Out:
# city                                      Abu Dhabi  Ahmedabad  Bengaluru  \
# team                        battingfirst
# Chennai Super Kings         False          3.666667        NaN        8.0
#                             True           5.000000        NaN        NaN
# Delhi Capitals              False          6.666667   3.333333        6.0
#                             True           3.500000        NaN        NaN
# Kolkata Knight Riders       False          6.000000   5.000000        5.0
#                             True           6.666667   6.000000        NaN
# Mumbai Indians              False          4.000000        NaN        NaN
#                             True           5.400000        NaN        8.0
# Punjab Kings                False          6.500000        NaN        7.0
#                             True           5.000000   6.666667        NaN
# Rajasthan Royals            False          4.500000        NaN        1.0
# ...

# %%
h = datadf.groupby(["fullName", "city", "team"])["tp"].mean().unstack(level="city")

# %%
dd = h["Dubai"]

# %%
ddd = dd.unstack(level="team")

# %%
ddd["Chennai Super Kings"].sort_values()
# Out:
# fullName
# Monu Kumar              -2.000000
# Imran Tahir              0.000000
# Josh Hazlewood           0.000000
# Kedar Jadhav             8.666667
# Narayan Jagadeesan      12.333333
# Dwayne Bravo            16.500000
# Murali Vijay            17.000000
# Deepak Chahar           22.714286
# MS Dhoni                25.571429
# Piyush Chawla           27.000000
# Karn Sharma             27.666667
# Mitchell Santner        30.000000
# Sam Curran              36.714286
# Shane Watson            37.500000
# Ravindra Jadeja         38.428571
# Shardul Thakur          40.000000
# Ambati Rayudu           41.000000
# Faf du Plessis          43.000000
# Lungi Ngidi             50.000000
# Ruturaj Gaikwad         64.000000
# AB de Villiers                NaN
# Aaron Finch                   NaN
# Abdul Samad                   NaN
# Abhishek Sharma               NaN
# Adam Milne                    NaN
# Adam Zampa                    NaN
# Ajinkya Rahane                NaN
# ...

# %%
ddd["Mumbai Indians"].sort_values()
# Out:
# fullName
# James Pattinson         -6.00
# Saurabh Tiwary           0.00
# Jayant Yadav            18.50
# Krunal Pandya           22.60
# Kieron Pollard          23.00
# Hardik Pandya           23.75
# Rahul Chahar            26.00
# Suryakumar Yadav        26.00
# Nathan Coulter-Nile     31.75
# Rohit Sharma            34.00
# Quinton de Kock         52.20
# Trent Boult             58.40
# Jasprit Bumrah          69.20
# Ishan Kishan            72.40
# AB de Villiers            NaN
# Aaron Finch               NaN
# Abdul Samad               NaN
# Abhishek Sharma           NaN
# Adam Milne                NaN
# Adam Zampa                NaN
# Ajinkya Rahane            NaN
# Akshdeep Nath             NaN
# Alex Carey                NaN
# Alzarri Joseph            NaN
# Ambati Rayudu             NaN
# Amit Mishra               NaN
# Andre Russell             NaN
# Andrew Tye                NaN
# Ankit Rajpoot             NaN
# Anrich Nortje             NaN
# ...

# %%
tdf[tdf["TeamName"] == "Punjab Kings"]
# Out:
#                   Name      TeamName      SkillName  Value  isUnCap   tp_x  \
# 4         Lokesh Rahul  Punjab Kings  WICKET KEEPER   11.5        0  63.00
# 5        Harpreet Brar  Punjab Kings         BOWLER    6.5        1  60.75
# 17      Mayank Agarwal  Punjab Kings        BATSMAN    9.5        0  52.11
# 20      Arshdeep Singh  Punjab Kings         BOWLER    7.5        1  50.38
# 27        Ravi Bishnoi  Punjab Kings         BOWLER    8.5        1  47.20
# 45      Mohammad Shami  Punjab Kings         BOWLER    9.0        0  39.40
# 50         Dawid Malan  Punjab Kings        BATSMAN    8.5        0  37.00
# 55     Jhye Richardson  Punjab Kings         BOWLER    8.5        0  35.33
# 70        Chris Jordan  Punjab Kings         BOWLER    8.0        0  31.67
# 74         Chris Gayle  Punjab Kings        BATSMAN    9.5        0  29.89
# 81        Deepak Hooda  Punjab Kings        BATSMAN    7.0        1  26.90
# ...

# %%
tdf[tdf["TeamName"] == "Mumbai Indians"]
# Out:
#                     Name        TeamName      SkillName  Value  isUnCap  \
# 0             Chris Lynn  Mumbai Indians        BATSMAN    9.0        0
# 26          Rohit Sharma  Mumbai Indians        BATSMAN   12.0        0
# 40        Jasprit Bumrah  Mumbai Indians         BOWLER   11.0        0
# 42       Quinton de Kock  Mumbai Indians  WICKET KEEPER   10.5        0
# 46        Kieron Pollard  Mumbai Indians    ALL ROUNDER    9.5        0
# 49           Trent Boult  Mumbai Indians         BOWLER    9.5        0
# 53          Rahul Chahar  Mumbai Indians         BOWLER    8.5        0
# 61        Saurabh Tiwary  Mumbai Indians        BATSMAN    7.0        0
# 73      Suryakumar Yadav  Mumbai Indians        BATSMAN    9.5        0
# 79          Marco Jansen  Mumbai Indians    ALL ROUNDER    6.5        0
# 84            Adam Milne  Mumbai Indians         BOWLER    8.0        0
# 85         Krunal Pandya  Mumbai Indians    ALL ROUNDER    8.5        0
# ...

# %%
tdf
# Out:
#                      Name                     TeamName      SkillName  Value  \
# 0              Chris Lynn               Mumbai Indians        BATSMAN    9.0
# 1           Harpreet Brar                 Punjab Kings         BOWLER    6.5
# 2             Imran Tahir          Chennai Super Kings         BOWLER    8.5
# 3          Venkatesh Iyer        Kolkata Knight Riders    ALL ROUNDER    6.0
# 4            Lokesh Rahul                 Punjab Kings  WICKET KEEPER   11.5
# 5          Shikhar Dhawan               Delhi Capitals        BATSMAN   10.5
# 6           Anrich Nortje               Delhi Capitals         BOWLER    9.0
# 7          Mahipal Lomror             Rajasthan Royals        BATSMAN    6.5
# 8           Harshal Patel  Royal Challengers Bangalore         BOWLER    7.0
# 9               Moeen Ali          Chennai Super Kings    ALL ROUNDER    8.5
# 10           Chris Morris             Rajasthan Royals    ALL ROUNDER    9.0
# ...

# %%
h
# Out:
# city          Abu Dhabi  Ahmedabad  Bengaluru    Chennai      Delhi  \
# bowlingStyle
# 0             32.831169  42.500000  32.187500  25.541667  33.277778
# FAST_SEAM     36.911111  28.678571  35.625000  35.000000  31.953488
# LEG_SPIN      29.428571  25.083333  32.800000  41.454545  42.452381
# MEDIUM_SEAM   30.903226  33.904762  37.348837  33.491803  29.854545
# OFF_SPIN      35.705882  30.620690  36.600000  32.442105  35.080000
# ORTHODOX      24.481481  59.833333  28.666667  35.117647  39.800000
# UNORTHODOX     3.250000        NaN  33.000000   6.000000  59.000000
#
# city              Dubai  Hyderabad     Jaipur    Kolkata     Mohali  \
# bowlingStyle
# 0             35.629213  29.192308  36.906250  32.937500  37.214286
# FAST_SEAM     39.648352  59.642857  24.956522  45.863636  43.250000
# LEG_SPIN      33.138614  48.677419  40.096774  34.000000  27.272727
# MEDIUM_SEAM   33.724359  36.951613  29.850000  23.821429  32.515152
# ...

# %%
tdf[tdf["TeamName"] == "Royal Challengers Bangalore"]
# Out:
#                      Name                     TeamName      SkillName  Value  \
# 5           Harshal Patel  Royal Challengers Bangalore         BOWLER    7.0
# 19         AB de Villiers  Royal Challengers Bangalore  WICKET KEEPER   11.0
# 27       Devdutt Padikkal  Royal Challengers Bangalore        BATSMAN    9.0
# 29          Glenn Maxwell  Royal Challengers Bangalore    ALL ROUNDER    9.0
# 31            Virat Kohli  Royal Challengers Bangalore        BATSMAN   12.0
# 41          Kyle Jamieson  Royal Challengers Bangalore         BOWLER    8.5
# 50          Shahbaz Ahmed  Royal Challengers Bangalore    ALL ROUNDER    6.5
# 58        Kane Richardson  Royal Challengers Bangalore         BOWLER    8.0
# 66         Mohammed Siraj  Royal Challengers Bangalore         BOWLER    8.0
# 76          Rajat Patidar  Royal Challengers Bangalore        BATSMAN    6.5
# 95      Washington Sundar  Royal Challengers Bangalore    ALL ROUNDER    8.5
# ...

# %%
tdf[tdf["TeamName"] == "Punjab Kings"]
# Out:
#                   Name      TeamName      SkillName  Value  isUnCap   tp_x  \
# 0        Harpreet Brar  Punjab Kings         BOWLER    6.5        1  96.50
# 6         Lokesh Rahul  Punjab Kings  WICKET KEEPER   11.5        0  66.29
# 19      Mayank Agarwal  Punjab Kings        BATSMAN    9.5        0  51.71
# 48         Dawid Malan  Punjab Kings        BATSMAN    8.5        0  37.00
# 52     Jhye Richardson  Punjab Kings         BOWLER    8.5        0  35.33
# 55        Ravi Bishnoi  Punjab Kings         BOWLER    8.5        1  34.75
# 58      Arshdeep Singh  Punjab Kings         BOWLER    7.5        1  33.50
# 66        Deepak Hooda  Punjab Kings        BATSMAN    7.0        1  31.88
# 68        Chris Jordan  Punjab Kings         BOWLER    8.0        0  31.67
# 71         Chris Gayle  Punjab Kings        BATSMAN    9.5        0  30.75
# 77      Mohammad Shami  Punjab Kings         BOWLER    9.0        0  28.38
# ...

# %%
tdf[tdf["TeamName"] == "Rajasthan Royals"]
# Out:
#                   Name          TeamName      SkillName  Value  isUnCap  \
# 6         Chris Morris  Rajasthan Royals    ALL ROUNDER    9.0        0
# 12        Sanju Samson  Rajasthan Royals  WICKET KEEPER    9.5        0
# 14         Jos Buttler  Rajasthan Royals  WICKET KEEPER   10.5        0
# 35      Jaydev Unadkat  Rajasthan Royals         BOWLER    8.0        0
# 53   Mustafizur Rahman  Rajasthan Royals         BOWLER    8.5        0
# 55         Shivam Dube  Rajasthan Royals    ALL ROUNDER    7.5        0
# 62    Yashasvi Jaiswal  Rajasthan Royals        BATSMAN    7.0        1
# 65     Chetan Sakariya  Rajasthan Royals         BOWLER    6.0        1
# 74         Riyan Parag  Rajasthan Royals        BATSMAN    7.5        1
# 77        David Miller  Rajasthan Royals        BATSMAN    8.0        0
# 80        Kartik Tyagi  Rajasthan Royals         BOWLER    7.0        1
# 86          Anuj Rawat  Rajasthan Royals  WICKET KEEPER    6.0        1
# ...

# %%
tdf[tdf["TeamName"] == "Sunrisers Hyderabad"]
# Out:
#                    Name             TeamName      SkillName  Value  isUnCap  \
# 0          Jason Holder  Sunrisers Hyderabad    ALL ROUNDER    9.0        0
# 15        Manish Pandey  Sunrisers Hyderabad        BATSMAN    9.0        0
# 22          Rashid Khan  Sunrisers Hyderabad         BOWLER   10.5        0
# 23       Jonny Bairstow  Sunrisers Hyderabad  WICKET KEEPER    9.5        0
# 33         David Warner  Sunrisers Hyderabad        BATSMAN   12.0        0
# 41      Kane Williamson  Sunrisers Hyderabad        BATSMAN    9.5        0
# 65       Shahbaz Nadeem  Sunrisers Hyderabad         BOWLER    7.5        0
# 66        Mohammad Nabi  Sunrisers Hyderabad    ALL ROUNDER    8.5        0
# 84          T Natarajan  Sunrisers Hyderabad         BOWLER    8.5        0
# 85      Abhishek Sharma  Sunrisers Hyderabad        BATSMAN    6.5        1
# 86        Siddarth Kaul  Sunrisers Hyderabad         BOWLER    7.5        0
# ...

# %%
tdf[tdf["TeamName"] == "Mumbai Indians"]
# Out:
#                     Name        TeamName      SkillName  Value  isUnCap  \
# 0             Chris Lynn  Mumbai Indians        BATSMAN    9.0        0
# 8         Saurabh Tiwary  Mumbai Indians        BATSMAN    7.0        0
# 30          Rohit Sharma  Mumbai Indians        BATSMAN   12.0        0
# 33        Kieron Pollard  Mumbai Indians    ALL ROUNDER    9.5        0
# 39          Rahul Chahar  Mumbai Indians         BOWLER    8.5        0
# 40            Adam Milne  Mumbai Indians         BOWLER    8.0        0
# 43           Trent Boult  Mumbai Indians         BOWLER    9.5        0
# 58       Quinton de Kock  Mumbai Indians  WICKET KEEPER   10.5        0
# 61      Suryakumar Yadav  Mumbai Indians        BATSMAN    9.5        0
# 73         Krunal Pandya  Mumbai Indians    ALL ROUNDER    8.5        0
# 76        Jasprit Bumrah  Mumbai Indians         BOWLER   11.0        0
# 80          Marco Jansen  Mumbai Indians    ALL ROUNDER    6.5        0
# ...

# %%
tdf[tdf["TeamName"] == "Kolkata Knight Riders"]
# Out:
#                      Name               TeamName      SkillName  Value  \
# 11        Lockie Ferguson  Kolkata Knight Riders         BOWLER    8.5
# 17         Venkatesh Iyer  Kolkata Knight Riders    ALL ROUNDER    6.0
# 28          Andre Russell  Kolkata Knight Riders    ALL ROUNDER   11.0
# 45     Varun Chakravarthy  Kolkata Knight Riders         BOWLER    8.0
# 47            Pat Cummins  Kolkata Knight Riders         BOWLER    9.5
# 56            Nitish Rana  Kolkata Knight Riders        BATSMAN    8.5
# 57        Shakib Al Hasan  Kolkata Knight Riders    ALL ROUNDER    9.0
# 64         Rahul Tripathi  Kolkata Knight Riders        BATSMAN    7.5
# 71        Prasidh Krishna  Kolkata Knight Riders         BOWLER    8.0
# 74           Shubman Gill  Kolkata Knight Riders        BATSMAN    9.0
# 85            Shivam Mavi  Kolkata Knight Riders         BOWLER    7.5
# 98           Sunil Narine  Kolkata Knight Riders    ALL ROUNDER    9.0
# ...

# %%
tdf
# Out:
#                      Name                     TeamName      SkillName  Value  \
# 0              Chris Lynn               Mumbai Indians        BATSMAN    9.0
# 1           Harpreet Brar                 Punjab Kings         BOWLER    6.5
# 2             Imran Tahir          Chennai Super Kings         BOWLER    8.5
# 3          Venkatesh Iyer        Kolkata Knight Riders    ALL ROUNDER    6.0
# 4            Lokesh Rahul                 Punjab Kings  WICKET KEEPER   11.5
# 5          Shikhar Dhawan               Delhi Capitals        BATSMAN   10.5
# 6               Moeen Ali          Chennai Super Kings    ALL ROUNDER    8.5
# 7           Anrich Nortje               Delhi Capitals         BOWLER    9.0
# 8          Mahipal Lomror             Rajasthan Royals        BATSMAN    6.5
# 9           Harshal Patel  Royal Challengers Bangalore         BOWLER    7.0
# 10        Ravindra Jadeja          Chennai Super Kings    ALL ROUNDER    9.0
# ...

# %%
datadf
# Out:
#      index  playerId             fullName    nationality  rightArmedBowl  \
# 0        0       107         Rohit Sharma         Indian            True
# 1        1       834      Quinton de Kock  South African           False
# 2        2       108     Suryakumar Yadav         Indian            True
# 3        3      2975         Ishan Kishan         Indian           False
# 4        4       163       Saurabh Tiwary         Indian            True
# 5        5       210       Kieron Pollard    West Indian            True
# 6        6      3183        Krunal Pandya         Indian           False
# 7        7      3763         Rahul Chahar         Indian            True
# 8        8       434           Adam Milne  New Zealander            True
# 9        9      1124       Jasprit Bumrah         Indian            True
# 10      10       969          Trent Boult  New Zealander           False
# 11      11      3761         Shubman Gill         Indian            True
# ...
